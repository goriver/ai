# %%
import pandas as pd
from fbprophet import Prophet

df = pd.read_csv("./temp_2018_train.csv")
m = Prophet()
m.fit(df)
future = m.make_future_dataframe(periods=10)
forecast=m.predict(future)
forecast[['ds','yhat','yhat_lower','yhat_upper']].tail(10)
# Out:
# ERROR:fbprophet:Importing plotly failed. Interactive plots will not work.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 15.
#            ds      yhat  yhat_lower  yhat_upper
# 20 2018-12-21  4.338744    1.420695    7.147883
# 21 2018-12-22  2.585610   -0.559459    5.267547
# 22 2018-12-23  0.485663   -2.590104    3.576258
# 23 2018-12-24  2.018986   -0.940887    5.004957
# 24 2018-12-25  3.885635    0.860709    7.021198
# 25 2018-12-26  4.085651    1.019537    6.983898
# 26 2018-12-27  1.952376   -1.195650    4.874843
# 27 2018-12-28  1.065189   -1.924914    3.994676
# 28 2018-12-29 -0.687945   -3.582510    2.341488
# 29 2018-12-30 -2.787892   -5.576941    0.256242

# %%
m.plot(forecast)

# %%
m.plot_components(forecast)

# %%
df = pd.read_csv("./temp_2018_train.csv")
df['cap']=20
df['floor']=-5
m = Prophet(growth='logistic')
m.fit(df)
future = m.make_future_dataframe(periods=10)
future['cap']=20
future['floor']=-5
forecast=m.predict(future)
forecast[['ds','yhat','yhat_lower','yhat_upper']].tail(10)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 15.
#            ds      yhat  yhat_lower  yhat_upper
# 20 2018-12-21  4.245175    1.123054    7.301132
# 21 2018-12-22  2.645320   -0.349522    5.436886
# 22 2018-12-23  0.556635   -2.479375    3.520044
# 23 2018-12-24  2.117720   -0.805241    5.132553
# 24 2018-12-25  4.028322    0.845481    7.146588
# 25 2018-12-26  4.288019    1.195290    6.965835
# 26 2018-12-27  2.229564   -1.016370    5.438056
# 27 2018-12-28  1.400563   -1.429047    4.494516
# 28 2018-12-29 -0.113508   -3.123069    2.971068
# 29 2018-12-30 -2.112560   -5.100178    0.981490

# %%
m.plot(forecast)

# %%
m.plot_components(forecast)

# %%
from fbprophet.plot import add_changepoints_to_plot

m = Prophet(changepoint_range=0.9)
m.fit(df)
future = m.make_future_dataframe(periods=10)
future['cap']=20
future['floor']=-5
forecast=m.predict(future)
forecast[['ds','yhat','yhat_lower','yhat_upper']]

fig = m.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), m, forecast)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 17.

# %%
m = Prophet(changepoint_range=0.1)
m.fit(df)
future = m.make_future_dataframe(periods=10)
future['cap']=20
future['floor']=-5
forecast=m.predict(future)
forecast[['ds','yhat','yhat_lower','yhat_upper']].tail(10)

fig = m.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), m, forecast)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations.Using 1.

# %%
df = pd.read_csv("./example_air_passengers.csv")
m = Prophet(seasonality_mode='multiplicative')
m.fit(df)
future = m.make_future_dataframe(periods=10)
forecast=m.predict(future)
m.plot(forecast)
fig = m.plot_components(forecast)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
