# %%
import pandas as pd
from fbprophet import Prophet

df = pd.read_csv("../dataset/temp_2018_train.csv")
m = Prophet()
m.fit(df)
future = m.make_future_dataframe(periods=10)
forecast=m.predict(future)
forecast[['ds','yhat','yhat_lower','yhat_upper']].tail(10)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 15.
#            ds      yhat  yhat_lower  yhat_upper
# 20 2018-12-21  4.338744    1.351482    7.364114
# 21 2018-12-22  2.585610   -0.478394    5.464352
# 22 2018-12-23  0.485663   -2.438585    3.383709
# 23 2018-12-24  2.018986   -0.962531    4.821204
# 24 2018-12-25  3.885635    0.943745    6.832184
# 25 2018-12-26  4.085651    1.185397    7.002215
# 26 2018-12-27  1.952376   -0.885710    4.899232
# 27 2018-12-28  1.065189   -1.872571    4.162693
# 28 2018-12-29 -0.687945   -3.284219    2.345244
# 29 2018-12-30 -2.787892   -5.628052    0.399116

# %%
m.plot(forecast)

# %%
m.plot_components(forecast)

# %%
df = pd.read_csv("../dataset/temp_2018_train.csv")
df['cap']=20
df['floor']=-5
m = Prophet(growth='logistic')
m.fit(df)
future = m.make_future_dataframe(periods=10)
future['cap']=20
future['floor']=-5
forecast=m.predict(future)
forecast[['ds','yhat','yhat_lower','yhat_upper']].tail(10)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 15.
#            ds      yhat  yhat_lower  yhat_upper
# 20 2018-12-21  4.245175    1.385414    7.434335
# 21 2018-12-22  2.645320   -0.306649    5.809299
# 22 2018-12-23  0.556635   -2.724553    3.513116
# 23 2018-12-24  2.117720   -0.949271    4.981402
# 24 2018-12-25  4.028322    0.988894    7.025585
# 25 2018-12-26  4.288019    1.144589    7.296670
# 26 2018-12-27  2.229564   -0.738559    5.461604
# 27 2018-12-28  1.400563   -1.390207    4.520802
# 28 2018-12-29 -0.113508   -3.227636    3.080218
# 29 2018-12-30 -2.112560   -5.101057    1.010878

# %%
m.plot(forecast)

# %%
m.plot_components(forecast)

# %%
from fbprophet.plot import add_changepoints_to_plot

m = Prophet(changepoint_range=0.9)
m.fit(df)
future = m.make_future_dataframe(periods=10)
future['cap']=20
future['floor']=-5
forecast=m.predict(future)
forecast[['ds','yhat','yhat_lower','yhat_upper']]

fig = m.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), m, forecast)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 17.

# %%
m = Prophet(changepoint_range=0.1)
m.fit(df)
future = m.make_future_dataframe(periods=10)
future['cap']=20
future['floor']=-5
forecast=m.predict(future)
forecast[['ds','yhat','yhat_lower','yhat_upper']].tail(10)

fig = m.plot(forecast)
a = add_changepoints_to_plot(fig.gca(), m, forecast)
# Out:
# INFO:fbprophet:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:fbprophet:n_changepoints greater than number of observations. Using 1.

# %%
df = pd.read_csv("../dataset/example_air_passengers.csv")
m = Prophet(seasonality_mode='multiplicative')
m.fit(df)
future = m.make_future_dataframe(periods=10)
forecast=m.predict(future)
m.plot(forecast)
fig = m.plot_components(forecast)
# Out:
# INFO:fbprophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
